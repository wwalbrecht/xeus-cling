// %% [markdown]
// # If-Test1
//
// ##  Lückentext_zu_if_nr001
//
// ### Welche Ausgabe liefert das folgende Programmfragment?

// %%
#include <iostream>

void testfunk_zu_if_nr001(void){
    int x= 10;
    int y= -10;
    int z= 0;
    if(x > -1){
        z++;
        if( y < 10){
            z++;
        } else {
            z--;
        }
    }
    std::cout << z << std::endl;
}// Ergebnis: ??

testfunk_zu_if_nr001();
// Out:
// 2

// %%
testfunk_zu_if_nr001();
// Out:
// 2

// %% [markdown]
// # P2_0_a_schleifen_selbst
//
// ## Lückentext_zu_schleifen_ws1920_a
//
// ### Welche Ausgaben liefert das folgende Programmfragment?

// %%
using namespace std;

// %%
void testfunk_zu_schleifen(void){
   int x= 0, z= 10;
    cout << z << endl; // Ausgabe: 10
    while( x < 3){
       x++;
       z--;
      if( x == 2){
          z= z - x;
          cout << x << endl; // Ausgabe: ??
          cout << z << endl; // Ausgabe: ??
      }
    }
    cout << x << endl;  // Ausgabe: ??
    cout << z << endl;  // Ausgabe: ??
}

testfunk_zu_schleifen();
// Out:
// 10
// 2
// 6
// 3
// 5

// %% [markdown]
// ### Welche Ausgaben liefert das folgende Programmfragment?

// %%
void testfunk_zu_sch1eifen(void){
    int x= 6, z= 0;
    while( x >= 5){
        if( x >= 6){
            z++;
        }
        z++;
        x--;
    }
    cout << x << endl; // Ausgabe: ??
    cout << z << endl; //  Ausgabe: ??
}

testfunk_zu_sch1eifen();
